# %% [markdown]
# # Ion Import
#
# ### Maricopa, Pinal, Pima

# %%
import pandas as pd
import re
from difflib import get_close_matches

# %%
maricopa = pd.read_csv('auction_data/maricopa.csv')
pima = pd.read_csv('auction_data/pima.csv')
pinal = pd.read_csv('auction_data/pinal.csv')

# %% [markdown]
# #### Add unique ID's & Market info to each county csv

# %%
#Maricopa

def format_apn(parcel):
    if pd.isna(parcel):
        return None
    
    parcel = parcel.strip()

    if len(parcel) == 8:
        return f"{parcel[:3]}-{parcel[3:5]}-{parcel[5:]}"
    elif len(parcel) == 9:
        return f"{parcel[:3]}-{parcel[3:5]}-{parcel[5:]}"
    else:
        return None

# Create APN column
maricopa["APN"] = maricopa["Parcel"].apply(format_apn)

#Create Market column
maricopa["Market"] = "Phoenix"

# %%
maricopa.head()
# Out:
#           ReportDate    County           SaleDate    Parcel  ParcelCount  \
# 0  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  11010049            1
# 1  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527161            1
# 2  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527160            1
# 3  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  20717044            1
# 4  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14022135            1
#
#   PropertyShortType      PropertyAddress PropertyCity PropertyState  \
# 0               SFR      3846 N 11TH AVE      PHOENIX            AZ
# 1               SFR       5046 N 41ST DR      PHOENIX            AZ
# 2             CONDO       5050 N 41ST DR      PHOENIX            AZ
# 3               SFR      16853 N 39TH DR      PHOENIX            AZ
# 4            MOBILE  3160 E MAIN ST #128         MESA            AZ
#
#    PropertyZip  ...  PropertyUseCode                          PropertyType  \
# 0        85013  ...            131.0      SFR GRADE 010-3 URBAN SUBDIVIDED
# 1        85019  ...            131.0      SFR GRADE 010-3 URBAN SUBDIVIDED
# 2        85019  ...           8530.0                       TH DEFAULT CODE
# 3        85053  ...            131.0      SFR GRADE 010-3 URBAN SUBDIVIDED
# 4        85213  ...            810.0  PLANNED MOBILE HOME SUBDIVISION SITE
#
#   ResCode           DeedDate   DeedFileNum  DeedAmount MortgageFileNum  \
# 0       R   7/2/2025 0:00:00  2.025038e+10  $430000.00      25-0383923
# 1       R   3/7/2023 0:00:00  2.023012e+10  $100000.00      24-0278466
# 2       R  5/11/2023 0:00:00  2.023025e+10       $0.00      24-0190559
# 3       R  4/18/2023 0:00:00  2.023020e+10  $254900.00      24-0209152
# 4       R   3/6/2024 0:00:00  2.024012e+10  $195000.00      24-0115955
#
#         MortgageDate         APN   Market
# 0   7/2/2025 0:00:00  110-10-049  Phoenix
# 1  5/24/2024 0:00:00  145-27-161  Phoenix
# 2  4/12/2024 0:00:00  145-27-160  Phoenix
# 3  4/22/2024 0:00:00  207-17-044  Phoenix
# 4   3/6/2024 0:00:00  140-22-135  Phoenix
#
# [5 rows x 40 columns]

# %%
#Pima

pima["Parcel"] = pima["Parcel"].astype(str)

# Create APN column
pima["APN"] = (
    "PIMA_AZ."
    + pima["Parcel"].str[:3]
    + "-"
    + pima["Parcel"].str[3:5]
    + "-"
    + pima["Parcel"].str[5:]
)

#Create Market column
pima["Market"] = "Tucson"

# %%
pima.head()
# Out:
#           ReportDate County           SaleDate     Parcel  ParcelCount  \
# 0  1/12/2026 0:00:00   PIMA  1/13/2026 0:00:00  217383830            1
# 1  1/12/2026 0:00:00   PIMA  1/13/2026 0:00:00  107091710            1
# 2  1/12/2026 0:00:00   PIMA  1/13/2026 0:00:00  134031400            1
# 3  1/12/2026 0:00:00   PIMA  1/13/2026 0:00:00  136062050            1
# 4  1/12/2026 0:00:00   PIMA  1/13/2026 0:00:00  118223180            1
#
#   PropertyShortType        PropertyAddress PropertyCity PropertyState  \
# 0               NaN  11742 W TOM HENRY WAY       MARANA            AZ
# 1             CONDO      2744 N PACIFIC DR       Tucson            AZ
# 2               SFR       8845 E ABRAMS LP       Tucson            AZ
# 3             CONDO     8927 E CALLE NORLO       Tucson            AZ
# 4               NaN          311 W 28TH ST       TUCSON            AZ
#
#    PropertyZip  ...  PropertyUseCode                      PropertyType  \
# 0        85653  ...              NaN                               NaN
# 1        85705  ...            730.0     CONDOS/TOWNHOUSES GRADE 070-3
# 2        85710  ...            131.0  SFR GRADE 010-3 URBAN SUBDIVIDED
# 3        85710  ...            730.0     CONDOS/TOWNHOUSES GRADE 070-3
# 4        85713  ...              NaN                               NaN
#
#    ResCode          DeedDate   DeedFileNum  DeedAmount MortgageFileNum  \
# 0        C               NaN           NaN       $0.00             NaN
# 1        R  8/1/2022 0:00:00  2.022241e+10  $190000.00      22-2410280
# 2        R  7/1/2017 0:00:00  2.017340e+10  $229570.00      20-1750929
# 3        R  3/1/2023 0:00:00  2.023089e+10  $242000.00      23-0890567
# 4        C               NaN           NaN       $0.00             NaN
#
#         MortgageDate                  APN  Market
# 0                NaN  PIMA_AZ.217-38-3830  Tucson
# 1  8/29/2022 0:00:00  PIMA_AZ.107-09-1710  Tucson
# 2  6/23/2020 0:00:00  PIMA_AZ.134-03-1400  Tucson
# 3  3/30/2023 0:00:00  PIMA_AZ.136-06-2050  Tucson
# 4                NaN  PIMA_AZ.118-22-3180  Tucson
#
# [5 rows x 40 columns]

# %%
#Pinal

pinal["Parcel"] = pinal["Parcel"].astype(str)

# Create APN column
pinal["APN"] = (
    "PINAL_AZ."
    + pinal["Parcel"].str[:3]
    + "-"
    + pinal["Parcel"].str[3:5]
    + "-"
    + pinal["Parcel"].str[5:]
)

#Create Market column
pinal["Market"] = "Phoenix"

# %%
pinal.head()
# Out:
#           ReportDate County           SaleDate     Parcel  ParcelCount  \
# 0  1/12/2026 0:00:00  PINAL  1/13/2026 0:00:00  509484680            1
# 1  1/12/2026 0:00:00  PINAL  1/13/2026 0:00:00  504530240            1
# 2  1/12/2026 0:00:00  PINAL  1/13/2026 0:00:00  209403050            1
# 3  1/12/2026 0:00:00  PINAL  1/13/2026 0:00:00  502450730            1
# 4  1/12/2026 0:00:00  PINAL  1/13/2026 0:00:00  502530850            1
#
#   PropertyShortType       PropertyAddress PropertyCity PropertyState  \
# 0               SFR   1126 E BROOKWOOD DR  CASA GRANDE            AZ
# 1               SFR    1854 N  CENTER AVE  CASA GRANDE            AZ
# 2               SFR     1350 N SIERRA AVE     COOLIDGE            AZ
# 3            MOBILE    14278 N RUSSELL RD     MARICOPA            AZ
# 4               SFR  35680 W VELAZQUEZ DR     MARICOPA            AZ
#
#    PropertyZip  ...  PropertyUseCode                      PropertyType  \
# 0        85122  ...              131  SFR GRADE 010-3 URBAN SUBDIVIDED
# 1        85122  ...              131  SFR GRADE 010-3 URBAN SUBDIVIDED
# 2        85128  ...              131  SFR GRADE 010-3 URBAN SUBDIVIDED
# 3        85138  ...              829    MH SUB LOT AFFIXED MOBILE HOME
# 4        85138  ...              131  SFR GRADE 010-3 URBAN SUBDIVIDED
#
#    ResCode            DeedDate DeedFileNum  DeedAmount MortgageFileNum  \
# 0        R    6/3/2025 0:00:00  2025045151         NaN       24-023311
# 1        R  12/29/2023 0:00:00  2023093826  $280000.00       23-093827
# 2        R   5/16/2023 0:00:00  2023035750  $339995.00       23-035751
# 3        R   4/17/2024 0:00:00  2024028081  $432000.00       24-028082
# 4        R  12/31/2019 0:00:00  2019112278         NaN       19-112279
#
#          MortgageDate                   APN   Market
# 0   3/29/2024 0:00:00  PINAL_AZ.509-48-4680  Phoenix
# 1   1/29/2023 0:00:00  PINAL_AZ.504-53-0240  Phoenix
# 2   5/16/2023 0:00:00  PINAL_AZ.209-40-3050  Phoenix
# 3   4/17/2024 0:00:00  PINAL_AZ.502-45-0730  Phoenix
# 4  12/31/2019 0:00:00  PINAL_AZ.502-53-0850  Phoenix
#
# [5 rows x 40 columns]

# %% [markdown]
# #### Combine all data to one csv

# %%
ionimport = pd.concat([maricopa, pima, pinal], ignore_index=True)

ionimport.to_csv("export_data/ionimport.csv", index=False)

# %%
ionimport.head()
# Out:
#           ReportDate    County           SaleDate    Parcel  ParcelCount  \
# 0  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  11010049            1
# 1  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527161            1
# 2  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527160            1
# 3  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  20717044            1
# 4  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14022135            1
#
#   PropertyShortType      PropertyAddress PropertyCity PropertyState  \
# 0               SFR      3846 N 11TH AVE      PHOENIX            AZ
# 1               SFR       5046 N 41ST DR      PHOENIX            AZ
# 2             CONDO       5050 N 41ST DR      PHOENIX            AZ
# 3               SFR      16853 N 39TH DR      PHOENIX            AZ
# 4            MOBILE  3160 E MAIN ST #128         MESA            AZ
#
#    PropertyZip  ...  PropertyUseCode                          PropertyType  \
# 0        85013  ...            131.0      SFR GRADE 010-3 URBAN SUBDIVIDED
# 1        85019  ...            131.0      SFR GRADE 010-3 URBAN SUBDIVIDED
# 2        85019  ...           8530.0                       TH DEFAULT CODE
# 3        85053  ...            131.0      SFR GRADE 010-3 URBAN SUBDIVIDED
# 4        85213  ...            810.0  PLANNED MOBILE HOME SUBDIVISION SITE
#
#   ResCode           DeedDate   DeedFileNum  DeedAmount MortgageFileNum  \
# 0       R   7/2/2025 0:00:00  2.025038e+10  $430000.00      25-0383923
# 1       R   3/7/2023 0:00:00  2.023012e+10  $100000.00      24-0278466
# 2       R  5/11/2023 0:00:00  2.023025e+10       $0.00      24-0190559
# 3       R  4/18/2023 0:00:00  2.023020e+10  $254900.00      24-0209152
# 4       R   3/6/2024 0:00:00  2.024012e+10  $195000.00      24-0115955
#
#         MortgageDate         APN   Market
# 0   7/2/2025 0:00:00  110-10-049  Phoenix
# 1  5/24/2024 0:00:00  145-27-161  Phoenix
# 2  4/12/2024 0:00:00  145-27-160  Phoenix
# 3  4/22/2024 0:00:00  207-17-044  Phoenix
# 4   3/6/2024 0:00:00  140-22-135  Phoenix
#
# [5 rows x 40 columns]

# %%
#Find duplicate APNs

duplicate_apns = ionimport[
    ionimport.duplicated(subset="APN", keep=False)
]

# View them
duplicate_apns.sort_values("APN")
# Out:
#            ReportDate    County           SaleDate    Parcel  ParcelCount  \
# 2   1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527160            1
# 6   1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527160            1
# 41  1/12/2026 0:00:00  MARICOPA  1/14/2026 0:00:00  50460616            1
# 42  1/12/2026 0:00:00  MARICOPA  1/14/2026 0:00:00  50460616            1
#
#    PropertyShortType        PropertyAddress PropertyCity PropertyState  \
# 2              CONDO         5050 N 41ST DR      PHOENIX            AZ
# 6              CONDO    4610 N 68TH ST #437   SCOTTSDALE            AZ
# 41               SFR  25884 W ELIZABETH AVE      BUCKEYE            AZ
# 42               SFR  25884 W ELIZABETH AVE      BUCKEYE            AZ
#
#     PropertyZip  ...  PropertyUseCode                           PropertyType  \
# 2         85019  ...           8530.0                        TH DEFAULT CODE
# 6         85251  ...            735.0  CONDOS/TH GRADE 070-3 COM AREA NOT PA
# 41        85326  ...            131.0       SFR GRADE 010-3 URBAN SUBDIVIDED
# 42        85326  ...            131.0       SFR GRADE 010-3 URBAN SUBDIVIDED
#
#    ResCode           DeedDate   DeedFileNum  DeedAmount MortgageFileNum  \
# 2        R  5/11/2023 0:00:00  2.023025e+10       $0.00      24-0190559
# 6        R  5/11/2023 0:00:00  2.023025e+10  $283000.00      24-0407729
# 41       R  4/29/2022 0:00:00  2.022038e+10  $420000.00      22-0378332
# 42       R  4/29/2022 0:00:00  2.022038e+10  $420000.00      22-0378332
#
#          MortgageDate         APN   Market
# 2   4/12/2024 0:00:00  145-27-160  Phoenix
# 6   7/31/2024 0:00:00  145-27-160  Phoenix
# 41  4/29/2022 0:00:00  504-60-616  Phoenix
# 42  4/29/2022 0:00:00  504-60-616  Phoenix
#
# [4 rows x 40 columns]

# %%
#Remove duplicate apns

ionimport.drop_duplicates(['APN'], keep = 'first', inplace=True)

# %% [markdown]
# #### Add columns for full address and properly formatted recording number

# %%
#Full address
#Labeled as 'Last Name' for Salesforce Lead object purposes

ionimport["Last Name"] = (
    ionimport["PropertyAddress"].fillna("").astype(str)
    + ", "
    + ionimport["PropertyCity"].fillna("").astype(str)
    + ", "
    + ionimport["PropertyState"].fillna("").astype(str)
    + " "
    + ionimport["PropertyZip"].fillna("").astype(str)
)

ionimport["Last Name"] = ionimport["Last Name"].str.title()

# %%
ionimport.head()
# Out:
#           ReportDate    County           SaleDate    Parcel  ParcelCount  \
# 0  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  11010049            1
# 1  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527161            1
# 2  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527160            1
# 3  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  20717044            1
# 4  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14022135            1
#
#   PropertyShortType      PropertyAddress PropertyCity PropertyState  \
# 0               SFR      3846 N 11TH AVE      PHOENIX            AZ
# 1               SFR       5046 N 41ST DR      PHOENIX            AZ
# 2             CONDO       5050 N 41ST DR      PHOENIX            AZ
# 3               SFR      16853 N 39TH DR      PHOENIX            AZ
# 4            MOBILE  3160 E MAIN ST #128         MESA            AZ
#
#    PropertyZip  ...                          PropertyType  ResCode  \
# 0        85013  ...      SFR GRADE 010-3 URBAN SUBDIVIDED        R
# 1        85019  ...      SFR GRADE 010-3 URBAN SUBDIVIDED        R
# 2        85019  ...                       TH DEFAULT CODE        R
# 3        85053  ...      SFR GRADE 010-3 URBAN SUBDIVIDED        R
# 4        85213  ...  PLANNED MOBILE HOME SUBDIVISION SITE        R
#
#             DeedDate   DeedFileNum  DeedAmount MortgageFileNum  \
# 0   7/2/2025 0:00:00  2.025038e+10  $430000.00      25-0383923
# 1   3/7/2023 0:00:00  2.023012e+10  $100000.00      24-0278466
# 2  5/11/2023 0:00:00  2.023025e+10       $0.00      24-0190559
# 3  4/18/2023 0:00:00  2.023020e+10  $254900.00      24-0209152
# 4   3/6/2024 0:00:00  2.024012e+10  $195000.00      24-0115955
#
#         MortgageDate         APN   Market                            Last Name
# 0   7/2/2025 0:00:00  110-10-049  Phoenix   3846 N 11Th Ave, Phoenix, Az 85013
# 1  5/24/2024 0:00:00  145-27-161  Phoenix    5046 N 41St Dr, Phoenix, Az 85019
# 2  4/12/2024 0:00:00  145-27-160  Phoenix    5050 N 41St Dr, Phoenix, Az 85019
# 3  4/22/2024 0:00:00  207-17-044  Phoenix   16853 N 39Th Dr, Phoenix, Az 85053
# 4   3/6/2024 0:00:00  140-22-135  Phoenix  3160 E Main St #128, Mesa, Az 85213
#
# [5 rows x 41 columns]

# %%
#Remove any addresses that are vacant land

ionimport = ionimport[
    ~ionimport["Last Name"].str.contains("vacant", case=False, na=False)
]

#ionimport[ionimport["Last Name"].str.contains("vacant", case=False, na=False)]

# %%
#NS Recording number

ionimport["NS Recording Number"] = (
    "20"
    + ionimport["NTFileNum"].str[:2]
    + ionimport["NTFileNum"].str[3:]
)

# %%
ionimport.head()
# Out:
#           ReportDate    County           SaleDate    Parcel  ParcelCount  \
# 0  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  11010049            1
# 1  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527161            1
# 2  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527160            1
# 3  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  20717044            1
# 4  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14022135            1
#
#   PropertyShortType      PropertyAddress PropertyCity PropertyState  \
# 0               SFR      3846 N 11TH AVE      PHOENIX            AZ
# 1               SFR       5046 N 41ST DR      PHOENIX            AZ
# 2             CONDO       5050 N 41ST DR      PHOENIX            AZ
# 3               SFR      16853 N 39TH DR      PHOENIX            AZ
# 4            MOBILE  3160 E MAIN ST #128         MESA            AZ
#
#    PropertyZip  ...  ResCode           DeedDate   DeedFileNum  DeedAmount  \
# 0        85013  ...        R   7/2/2025 0:00:00  2.025038e+10  $430000.00
# 1        85019  ...        R   3/7/2023 0:00:00  2.023012e+10  $100000.00
# 2        85019  ...        R  5/11/2023 0:00:00  2.023025e+10       $0.00
# 3        85053  ...        R  4/18/2023 0:00:00  2.023020e+10  $254900.00
# 4        85213  ...        R   3/6/2024 0:00:00  2.024012e+10  $195000.00
#
#   MortgageFileNum       MortgageDate         APN   Market  \
# 0      25-0383923   7/2/2025 0:00:00  110-10-049  Phoenix
# 1      24-0278466  5/24/2024 0:00:00  145-27-161  Phoenix
# 2      24-0190559  4/12/2024 0:00:00  145-27-160  Phoenix
# 3      24-0209152  4/22/2024 0:00:00  207-17-044  Phoenix
# 4      24-0115955   3/6/2024 0:00:00  140-22-135  Phoenix
#
#                              Last Name NS Recording Number
# 0   3846 N 11Th Ave, Phoenix, Az 85013         20250587640
# 1    5046 N 41St Dr, Phoenix, Az 85019         20250348285
# 2    5050 N 41St Dr, Phoenix, Az 85019         20250348286
# 3   16853 N 39Th Dr, Phoenix, Az 85053         20250348283
# 4  3160 E Main St #128, Mesa, Az 85213         20250590304
#
# [5 rows x 42 columns]

# %% [markdown]
# #### Misc. Checks

# %%
#Find any 1900 year end dates in DeedDate

ionimport["DeedDate"] = pd.to_datetime(ionimport["DeedDate"], errors="coerce")

ionimport.loc[
    ionimport["DeedDate"].dt.year < 1901,
    "DeedDate"
] = pd.NaT

# %%
ionimport["DeedDate"].dt.year.value_counts(dropna=False).sort_index()
# Out:
# DeedDate
# 1987.0     2
# 2000.0     1
# 2001.0     2
# 2002.0     1
# 2003.0     2
# 2004.0     4
# 2006.0     3
# 2010.0     1
# 2011.0     1
# 2012.0     4
# 2013.0     4
# 2014.0     5
# 2015.0     2
# 2016.0    11
# 2017.0     2
# 2018.0     6
# 2019.0     8
# 2020.0    14
# 2021.0    28
# 2022.0    42
# 2023.0    26
# 2024.0    19
# 2025.0     6
# NaN       14
# Name: count, dtype: int64

# %%
#Change currency columns to numbers

for col in ["DeedAmount", "MortgageAmount"]:
    ionimport.loc[:, col] = (
        ionimport[col]
        .astype(str)
        .str.replace(r"[\$,]", "", regex=True)
        .astype(float)
    )

# %%
ionimport.head()
# Out:
#           ReportDate    County           SaleDate    Parcel  ParcelCount  \
# 0  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  11010049            1
# 1  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527161            1
# 2  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14527160            1
# 3  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  20717044            1
# 4  1/12/2026 0:00:00  MARICOPA  1/12/2026 0:00:00  14022135            1
#
#   PropertyShortType      PropertyAddress PropertyCity PropertyState  \
# 0               SFR      3846 N 11TH AVE      PHOENIX            AZ
# 1               SFR       5046 N 41ST DR      PHOENIX            AZ
# 2             CONDO       5050 N 41ST DR      PHOENIX            AZ
# 3               SFR      16853 N 39TH DR      PHOENIX            AZ
# 4            MOBILE  3160 E MAIN ST #128         MESA            AZ
#
#    PropertyZip  ...  ResCode   DeedDate   DeedFileNum  DeedAmount  \
# 0        85013  ...        R 2025-07-02  2.025038e+10    430000.0
# 1        85019  ...        R 2023-03-07  2.023012e+10    100000.0
# 2        85019  ...        R 2023-05-11  2.023025e+10         0.0
# 3        85053  ...        R 2023-04-18  2.023020e+10    254900.0
# 4        85213  ...        R 2024-03-06  2.024012e+10    195000.0
#
#   MortgageFileNum       MortgageDate         APN   Market  \
# 0      25-0383923   7/2/2025 0:00:00  110-10-049  Phoenix
# 1      24-0278466  5/24/2024 0:00:00  145-27-161  Phoenix
# 2      24-0190559  4/12/2024 0:00:00  145-27-160  Phoenix
# 3      24-0209152  4/22/2024 0:00:00  207-17-044  Phoenix
# 4      24-0115955   3/6/2024 0:00:00  140-22-135  Phoenix
#
#                              Last Name NS Recording Number
# 0   3846 N 11Th Ave, Phoenix, Az 85013         20250587640
# 1    5046 N 41St Dr, Phoenix, Az 85019         20250348285
# 2    5050 N 41St Dr, Phoenix, Az 85019         20250348286
# 3   16853 N 39Th Dr, Phoenix, Az 85053         20250348283
# 4  3160 E Main St #128, Mesa, Az 85213         20250590304
#
# [5 rows x 42 columns]

# %%
#Make county not all caps

ionimport["County"] = ionimport["County"].str.title()

# %%
#Change column names
ionimport = ionimport.rename(columns={
    "SaleDate": "Auction Date Updated",
    "PropertyShortType": "Type of Property",
    "BldgSquareFeet": "Bldg Sq Ft",
    "LotSquareFeet": "Lot Sq Ft",
    "YearBuilt": "Year Built",
    "MortgageAmount": "Mortgage",
    "SaleLocation": "Auction Location Lookup",
    "SaleTime": "Auction Sale Time",
    "Trustee": "Auction Trustee",
    "TrusteeSaleNum": "NS Trustee Sale Number",
    "DeedDate": "Deed Date",
    "DeedAmount": "Deed"
})

# %%
ionimport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 208 entries, 0 to 209
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ReportDate               208 non-null    object
#  1   County                   208 non-null    object
#  2   Auction Date Updated     208 non-null    object
#  3   Parcel                   208 non-null    object
#  4   ParcelCount              208 non-null    int64
#  5   Type of Property         201 non-null    object
#  6   PropertyAddress          208 non-null    object
#  7   PropertyCity             208 non-null    object
#  8   PropertyState            208 non-null    object
#  9   PropertyZip              208 non-null    int64
#  10  Bldg Sq Ft               208 non-null    int64
#  11  Lot Sq Ft                208 non-null    int64
#  12  Pool                     41 non-null     object
#  13  Year Built               194 non-null    float64
#  14  OpenBidAmount            208 non-null    object
#  15  EstimatedAmount          208 non-null    object
#  16  AssessedAmount           208 non-null    object
#  17  Mortgage                 208 non-null    object
#  18  TaxYear                  201 non-null    float64
#  19  Subdivision              199 non-null    object
#  20  Lot                      186 non-null    object
#  21  Auction Location Lookup  207 non-null    object
#  22  Auction Sale Time        208 non-null    object
#  23  Auction Trustee          208 non-null    object
#  24  TrusteePhone             208 non-null    int64
#  25  TrusteeAddress           201 non-null    object
#  26  NS Trustee Sale Number   208 non-null    object
#  27  NTFileNum                208 non-null    object
#  28  Trustor                  201 non-null    object
#  29  Beneficiary              201 non-null    object
#  30  PropertyUseCode          201 non-null    float64
#  31  PropertyType             201 non-null    object
#  32  ResCode                  208 non-null    object
#  33  Deed Date                194 non-null    datetime64[ns]
#  34  DeedFileNum              195 non-null    float64
#  35  Deed                     191 non-null    object
#  36  MortgageFileNum          201 non-null    object
#  37  MortgageDate             201 non-null    object
#  38  APN                      208 non-null    object
#  39  Market                   208 non-null    object
#  40  Last Name                208 non-null    object
#  41  NS Recording Number      208 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(32)
# memory usage: 69.9+ KB

# %% [markdown]
# "SaleDate" to Auction Date Updated
# "PropertyShortType" to Type of Property
# "BldgSquareFeet" to Bldg Sq Ft
# "LotSquareFeet" to Lot Sq Ft
# "YearBuilt" to Year Built
# "MortgageAmount" to Mortgage
# "SaleLocation" to Auction Location (Lookup)
# "SaleTime" to Auction Sale Time
# "Trustee" to Auction Trustee
# "TrusteeSaleNum" to NS Trustee Sale Number
# "DeedDate" to Deed Date
# "DeedAmount" to Deed

# %%
#Update Auction Sale time to "10:00"

ionimport["Auction Sale Time"] = (
    pd.to_datetime(ionimport["Auction Sale Time"])
      .dt.strftime("%H:%M")
)

# %% [markdown]
# #### Auction Trustee Lookup

# %%
contacts = pd.read_csv('sf_data/trusteecontacts.csv')

# %%
contacts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Contact: Contact Name  234 non-null    object
#  1   Associated Names       23 non-null     object
# dtypes: object(2)
# memory usage: 3.8+ KB

# %%
# Clean up column names if there are leading/trailing spaces
contacts.columns = contacts.columns.str.strip()

# %%
def norm(s):
    if pd.isna(s):
        return ""
    s = str(s).upper()
    s = s.replace("\u00A0", " ")              # non-breaking spaces
    s = re.sub(r"[^\w\s]", " ", s)            # remove punctuation
    s = re.sub(r"\s+", " ", s).strip()        # collapse spaces
    return s

contacts["contact_name_norm"] = contacts["Contact: Contact Name"].map(norm)
contacts["assoc_norm"] = contacts["Associated Names"].map(norm)  # can be blank

# %%
ionimport["trustee_norm"] = ionimport["Auction Trustee"].map(norm)

# %%
exact_map = dict(zip(contacts["contact_name_norm"], contacts["Contact: Contact Name"]))
ionimport["Auction Trustee (Lookup)"] = ionimport["trustee_norm"].map(exact_map)

# %%
def contains_in_contact_name(trustee_norm_value: str):
    if not trustee_norm_value:
        return None

    # find first contact where contact name contains trustee value
    hits = contacts.loc[
        contacts["contact_name_norm"].str.contains(re.escape(trustee_norm_value), na=False),
        "Contact: Contact Name"
    ]
    return hits.iloc[0] if len(hits) else None

mask = ionimport["Auction Trustee (Lookup)"].isna() & (ionimport["trustee_norm"] != "")
ionimport.loc[mask, "Auction Trustee (Lookup)"] = ionimport.loc[mask, "trustee_norm"].map(contains_in_contact_name)

# %%
def contains_in_associated(trustee_norm_value: str):
    if not trustee_norm_value:
        return None

    hits = contacts.loc[
        contacts["assoc_norm"].str.contains(re.escape(trustee_norm_value), na=False),
        "Contact: Contact Name"
    ]
    return hits.iloc[0] if len(hits) else None

mask = ionimport["Auction Trustee (Lookup)"].isna() & (ionimport["trustee_norm"] != "")
ionimport.loc[mask, "Auction Trustee (Lookup)"] = ionimport.loc[mask, "trustee_norm"].map(contains_in_associated)

# %%
unmatched = (
    ionimport.loc[ionimport["Auction Trustee (Lookup)"].isna(), "Auction Trustee"]
    .dropna()
    .drop_duplicates()
    .sort_values()
)

# %%
ionimport.head()
# Out:
#           ReportDate    County Auction Date Updated    Parcel  ParcelCount  \
# 0  1/12/2026 0:00:00  Maricopa    1/12/2026 0:00:00  11010049            1
# 1  1/12/2026 0:00:00  Maricopa    1/12/2026 0:00:00  14527161            1
# 2  1/12/2026 0:00:00  Maricopa    1/12/2026 0:00:00  14527160            1
# 3  1/12/2026 0:00:00  Maricopa    1/12/2026 0:00:00  20717044            1
# 4  1/12/2026 0:00:00  Maricopa    1/12/2026 0:00:00  14022135            1
#
#   Type of Property      PropertyAddress PropertyCity PropertyState  \
# 0              SFR      3846 N 11TH AVE      PHOENIX            AZ
# 1              SFR       5046 N 41ST DR      PHOENIX            AZ
# 2            CONDO       5050 N 41ST DR      PHOENIX            AZ
# 3              SFR      16853 N 39TH DR      PHOENIX            AZ
# 4           MOBILE  3160 E MAIN ST #128         MESA            AZ
#
#    PropertyZip  ...   DeedFileNum      Deed MortgageFileNum  \
# 0        85013  ...  2.025038e+10  430000.0      25-0383923
# 1        85019  ...  2.023012e+10  100000.0      24-0278466
# 2        85019  ...  2.023025e+10       0.0      24-0190559
# 3        85053  ...  2.023020e+10  254900.0      24-0209152
# 4        85213  ...  2.024012e+10  195000.0      24-0115955
#
#         MortgageDate         APN   Market  \
# 0   7/2/2025 0:00:00  110-10-049  Phoenix
# 1  5/24/2024 0:00:00  145-27-161  Phoenix
# 2  4/12/2024 0:00:00  145-27-160  Phoenix
# 3  4/22/2024 0:00:00  207-17-044  Phoenix
# 4   3/6/2024 0:00:00  140-22-135  Phoenix
#
#                              Last Name NS Recording Number  \
# 0   3846 N 11Th Ave, Phoenix, Az 85013         20250587640
# 1    5046 N 41St Dr, Phoenix, Az 85019         20250348285
# 2    5050 N 41St Dr, Phoenix, Az 85019         20250348286
# 3   16853 N 39Th Dr, Phoenix, Az 85053         20250348283
# 4  3160 E Main St #128, Mesa, Az 85213         20250590304
#
#          trustee_norm                           Auction Trustee (Lookup)
# 0       RONALD B HERB                                     Ronald B. Herb
# 1       RONALD B HERB                                     Ronald B. Herb
# 2       RONALD B HERB                                     Ronald B. Herb
# 3       RONALD B HERB                                     Ronald B. Herb
# 4  JOHN L LOHR JR ESQ  John L. Lohr, Jr., Esq., HYMSON GOLDSTEIN PANT...
#
# [5 rows x 44 columns]

# %%
unmatched = (
    ionimport.loc[ionimport["Auction Trustee (Lookup)"].isna(),["Last Name", "Auction Trustee", "trustee_norm"]])

unmatched
# Out:
# Empty DataFrame
# Columns: [Last Name, Auction Trustee, trustee_norm]
# Index: []

# %%
missing = (
    ionimport.loc[ionimport["Auction Trustee (Lookup)"].isna(), "trustee_norm"]
    .dropna().drop_duplicates()
)

# which of these are present as a normalized contact name?
present_mask = missing.isin(contacts["contact_name_norm"])
missing_not_in_contacts = missing[~present_mask]

missing_not_in_contacts.head(50)
# Out:
# Series([], Name: trustee_norm, dtype: object)

# %% [markdown]
# #### Auction Locations

# %%
locations = pd.read_csv('sf_data/auctionlocations.csv')

# %%
lookup_set = set(locations["Auction Location: Auction Location"].dropna())

missing_values = (
    ionimport.loc[
        ionimport["Auction Location Lookup"].notna()
        & ~ionimport["Auction Location Lookup"].isin(lookup_set),
        "Auction Location Lookup"
    ]
    .drop_duplicates()
    .sort_values()
)

missing_values
# Out:
# Series([], Name: Auction Location Lookup, dtype: object)

# %%
ionimport.to_csv("export_data/ionimport.csv", index=False)
