# %% [markdown]
# ### Kansas City, St. Louis, and Springfield

# %%
import pandas as pd
import numpy as np
import re
from difflib import get_close_matches

# %%
kc = pd.read_csv('auction_data/kcmo.csv')
stl = pd.read_csv('auction_data/stl.csv')
spfd = pd.read_csv('auction_data/springfield.csv')

# %% [markdown]
# #### Add unique ID's & Market info to each county csv

# %%
#KC

# Create APN column
kc["APN"] = (
    "KCMO."
    + kc["Address"]
        .fillna("")
        .str.replace(" ", "_",regex = False)
        .str.upper()
    +"_"
    + kc["Zip"].astype(str)
)

#Create Market column
kc["Market"] = "Kansas City"

# %%
kc.head()
# Out:
#            County        Date   Time            Address           City    Zip  \
# 0     Cass County  01-12-2026  09:00     409 Vermont St  Pleasant Hill  64080
# 1  Jackson County  01-12-2026  10:00     814 S Crane St   Independence  64050
# 2  Jackson County  01-12-2026  10:00  7001 S Benton Ave    Kansas City  64132
# 3  Jackson County  01-12-2026  10:00   5921 Indiana Ave    Kansas City  64130
# 4  Jackson County  01-12-2026  10:00   4421 College Ave    Kansas City  64130
#
#                     Owner Name                                Mailing Address  \
# 0             Erin R Pickering        409 Vermont St, Pleasant Hill, MO 64080
# 1  SPS Platinum Properties LLC  511 Delaware St Ste 100 Kansas City, MO 64105
# 2  SPS Platinum Properties LLC       7001 S Benton Ave, Kansas City, MO 64132
# 3  SPS Platinum Properties LLC  10120 W Flamingo Rd Ste 4 Las Vegas, NV 89147
# 4  SPS Platinum Properties LLC  511 Delaware St Ste 100 Kansas City, MO 64105
#
#    Bedrooms  Bathrooms  ...  Opening Bid  Assessed Value Proj. Opening Bid  \
# 0       3.0        NaN  ...          NaN          204700          114778.0
# 1       3.0        1.0  ...          NaN          173500               NaN
# 2       3.0        1.0  ...          NaN          118700               NaN
# 3       3.0        1.0  ...          NaN          128800               NaN
# 4       2.0        1.0  ...          NaN          129900               NaN
#
#   Original Loan Amount                APN Number    Status  Action  Comments  \
# 0              89380.0                   1903700  Canceled     NaN       NaN
# 1             856000.0  26-620-06-17-00-0-00-000    Active     NaN       NaN
# 2             856000.0  46-420-28-02-00-0-00-000    Active     NaN       NaN
# 3             856000.0  46-310-02-20-00-0-00-000    Active     NaN       NaN
# 4             856000.0  31-420-16-04-00-0-00-000    Active     NaN       NaN
#
#                             APN       Market
# 0     KCMO.409_VERMONT_ST_64080  Kansas City
# 1     KCMO.814_S_CRANE_ST_64050  Kansas City
# 2  KCMO.7001_S_BENTON_AVE_64132  Kansas City
# 3   KCMO.5921_INDIANA_AVE_64130  Kansas City
# 4   KCMO.4421_COLLEGE_AVE_64130  Kansas City
#
# [5 rows x 26 columns]

# %%
#STL

# Create APN column
stl["APN"] = (
    "STL_MO."
    + stl["Address"]
        .fillna("")
        .str.replace(" ", "_",regex = False)
        .str.upper()
    +"_"
    + stl["Zip"].astype(str)
)

#Create Market column
stl["Market"] = "St. Louis"

# %%
stl.head()
# Out:
#                County        Date   Time            Address         City  \
# 0    St. Louis County  01-12-2026  09:30   3715 Bobring Ave    St. Louis
# 1    St. Louis County  01-12-2026  09:30        2 Gimlin Pl    St. Louis
# 2  St. Charles County  01-12-2026  10:00  607 Cora Belle Dr  St. Charles
# 3  St. Charles County  01-12-2026  10:00  120 Briarcliff Dr  St. Charles
# 4  St. Charles County  01-12-2026  10:00    2203 W Adams St  St. Charles
#
#      Zip                               Owner Name  \
# 0  63125     Michael A Morris and Marian T Morris
# 1  63138                        Marjorie V Dubray
# 2  63301  Jeffrey P Wilson and Priscilla M Wilson
# 3  63301                              Steven Sabo
# 4  63301        Jason C Cordes and Julee A Cordes
#
#                                 Mailing Address  Bedrooms  Bathrooms  ...  \
# 0       3715 Bobring Ave, Saint Louis, MO 63125       2.0        1.0  ...
# 1            2 Gimlin Pl, Saint Louis, MO 63138       3.0        2.0  ...
# 2    607 Cora Belle Dr, Saint Charles, MO 63301       2.0        2.0  ...
# 3    120 Briarcliff Dr, Saint Charles, MO 63301       3.0        3.0  ...
# 4  11 Becky Thatcher Dr Saint Charles, MO 63303       3.0        2.0  ...
#
#    Opening Bid  Assessed Value Proj. Opening Bid Original Loan Amount  \
# 0    103062.00          147600          317354.0             111881.0
# 1     24440.71          244500           32178.0              25000.0
# 2          NaN          194000          164227.0             114400.0
# 3          NaN          273500          256182.0             216015.0
# 4     55200.00           75000          214062.0             169750.0
#
#                     APN Number  Status  Action  Comments  \
# 0                  27H-63-0286  Active     NaN       NaN
# 1                  07E-41-0083  Active     NaN       NaN
# 2  5-0056-4425-08-0009.0000000  Active     NaN       NaN
# 3  6-0002-4951-00-0006.0000000  Active     NaN       NaN
# 4  6-006C-4055-00-0058.0000000  Active     NaN       NaN
#
#                               APN     Market
# 0   STL_MO.3715_BOBRING_AVE_63125  St. Louis
# 1        STL_MO.2_GIMLIN_PL_63138  St. Louis
# 2  STL_MO.607_CORA_BELLE_DR_63301  St. Louis
# 3  STL_MO.120_BRIARCLIFF_DR_63301  St. Louis
# 4    STL_MO.2203_W_ADAMS_ST_63301  St. Louis
#
# [5 rows x 26 columns]

# %%
#Springfield

# Create APN column
spfd["APN"] = (
    "SPRINGFIELD_MO."
    + spfd["Address"]
        .fillna("")
        .str.replace(" ", "_",regex = False)
        .str.upper()
    +"_"
    + spfd["Zip"].astype(str)
)

#Create Market column
spfd["Market"] = "Springfield"

# %%
spfd.head()
# Out:
#           County        Date   Time               Address         City    Zip  \
# 0  Greene County  01-12-2026  10:00      606 E Wayland St  Springfield  65807
# 1  Greene County  01-12-2026  10:00  2722 S Farm Road 115    Brookline  65619
# 2  Greene County  01-13-2026  14:25   4021 W Ridgeview St  Battlefield  65619
# 3  Greene County  01-13-2026  14:25       1129 W Scott St  Springfield  65802
# 4  Greene County  01-14-2026  12:00          704 N Ivy Ln    Strafford  65757
#
#                              Owner Name  \
# 0                     Carolee Ann Smith
# 1       Jonathan Larsen and John Larsen
# 2                        Dana L Richard
# 3                   Gwendolyn V Skipper
# 4  Roderick J Lavigne and Karen Lavigne
#
#                               Mailing Address  Bedrooms  Bathrooms  ...  \
# 0     606 E Wayland St, Springfield, MO 65807       4.0        2.0  ...
# 1   2722 S Farm Road 115, Brookline, MO 65619       3.0        3.0  ...
# 2  4021 W Ridgeview St, Battlefield, MO 65619       3.0        2.0  ...
# 3      1129 W Scott St, Springfield, MO 65802       5.0        3.0  ...
# 4           704 N Ivy Ln, Strafford, MO 65757       3.0        2.0  ...
#
#    Opening Bid  Assessed Value  Proj. Opening Bid Original Loan Amount  \
# 0     170520.0        257600.0                NaN              71225.0
# 1     240900.0        293800.0           409849.0             351500.0
# 2      34237.9        215500.0            77210.0              41000.0
# 3      46466.0        208100.0            71580.0              50720.0
# 4          NaN        243800.0           128015.0             101862.0
#
#       APN Number    Status  Action  Comments  \
# 0  13-36-314-005    Active     NaN       NaN
# 1  18-06-200-184    Active     NaN       NaN
# 2  18-20-200-243  Canceled     NaN       NaN
# 3  13-14-209-007    Active     NaN       NaN
# 4  10-35-200-013    Active     NaN       NaN
#
#                                          APN       Market
# 0      SPRINGFIELD_MO.606_E_WAYLAND_ST_65807  Springfield
# 1  SPRINGFIELD_MO.2722_S_FARM_ROAD_115_65619  Springfield
# 2   SPRINGFIELD_MO.4021_W_RIDGEVIEW_ST_65619  Springfield
# 3       SPRINGFIELD_MO.1129_W_SCOTT_ST_65802  Springfield
# 4          SPRINGFIELD_MO.704_N_IVY_LN_65757  Springfield
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Combine all data to one csv

# %%
davidimport = pd.concat([kc, stl, spfd], ignore_index=True)

davidimport.to_csv("export_data/davidimport.csv", index=False)

# %%
#Find duplicate APNs

duplicate_apns = davidimport[
    davidimport.duplicated(subset="APN", keep=False)
]

# View them
duplicate_apns.sort_values("APN")
# Out:
#             County        Date   Time         Address         City    Zip  \
# 88  Jackson County  02-12-2026  13:00  2516 Askew Ave  Kansas City  64127
# 89  Jackson County  02-12-2026  13:00  2516 Askew Ave  Kansas City  64127
#
#                                           Owner Name  \
# 88  Tania Sandoval and Jose Luis Sandoval De La Rosa
# 89                                Brenda Faye Munson
#
#                           Mailing Address  Bedrooms  Bathrooms  ...  \
# 88  2516 Askew Ave, Kansas City, MO 64127       3.0        1.0  ...
# 89  2516 Askew Ave, Kansas City, MO 64127       3.0        1.0  ...
#
#     Opening Bid  Assessed Value Proj. Opening Bid Original Loan Amount  \
# 88          NaN        110000.0          140186.0             143000.0
# 89     67809.01         86200.0           63702.0              90329.0
#
#    APN Number  Status  Action  Comments                        APN  \
# 88        NaN  Active     NaN       NaN  KCMO.2516_ASKEW_AVE_64127
# 89        NaN  Active     NaN       NaN  KCMO.2516_ASKEW_AVE_64127
#
#          Market
# 88  Kansas City
# 89  Kansas City
#
# [2 rows x 26 columns]

# %%
#Remove duplicate apns

davidimport.drop_duplicates(['APN'], keep = 'first', inplace=True)

# %% [markdown]
# #### Add Columns
# County, Last Name

# %%
#Full address
#Labeled as 'Last Name' for Salesforce Lead object purposes

davidimport["Last Name"] = (
    davidimport["Address"].fillna("").astype(str)
    + ", "
    + davidimport["City"].fillna("").astype(str)
    + ", MO "
    + davidimport["Zip"].fillna("").astype(str)
)

davidimport["Last Name"] = davidimport["Last Name"]

# %%
davidimport.head()
# Out:
#            County        Date   Time            Address           City    Zip  \
# 0     Cass County  01-12-2026  09:00     409 Vermont St  Pleasant Hill  64080
# 1  Jackson County  01-12-2026  10:00     814 S Crane St   Independence  64050
# 2  Jackson County  01-12-2026  10:00  7001 S Benton Ave    Kansas City  64132
# 3  Jackson County  01-12-2026  10:00   5921 Indiana Ave    Kansas City  64130
# 4  Jackson County  01-12-2026  10:00   4421 College Ave    Kansas City  64130
#
#                     Owner Name                                Mailing Address  \
# 0             Erin R Pickering        409 Vermont St, Pleasant Hill, MO 64080
# 1  SPS Platinum Properties LLC  511 Delaware St Ste 100 Kansas City, MO 64105
# 2  SPS Platinum Properties LLC       7001 S Benton Ave, Kansas City, MO 64132
# 3  SPS Platinum Properties LLC  10120 W Flamingo Rd Ste 4 Las Vegas, NV 89147
# 4  SPS Platinum Properties LLC  511 Delaware St Ste 100 Kansas City, MO 64105
#
#    Bedrooms  Bathrooms  ...  Assessed Value  Proj. Opening Bid  \
# 0       3.0        NaN  ...        204700.0           114778.0
# 1       3.0        1.0  ...        173500.0                NaN
# 2       3.0        1.0  ...        118700.0                NaN
# 3       3.0        1.0  ...        128800.0                NaN
# 4       2.0        1.0  ...        129900.0                NaN
#
#   Original Loan Amount                APN Number    Status Action  Comments  \
# 0              89380.0                   1903700  Canceled    NaN       NaN
# 1             856000.0  26-620-06-17-00-0-00-000    Active    NaN       NaN
# 2             856000.0  46-420-28-02-00-0-00-000    Active    NaN       NaN
# 3             856000.0  46-310-02-20-00-0-00-000    Active    NaN       NaN
# 4             856000.0  31-420-16-04-00-0-00-000    Active    NaN       NaN
#
#                             APN       Market  \
# 0     KCMO.409_VERMONT_ST_64080  Kansas City
# 1     KCMO.814_S_CRANE_ST_64050  Kansas City
# 2  KCMO.7001_S_BENTON_AVE_64132  Kansas City
# 3   KCMO.5921_INDIANA_AVE_64130  Kansas City
# 4   KCMO.4421_COLLEGE_AVE_64130  Kansas City
#
#                                   Last Name
# 0   409 Vermont St, Pleasant Hill, MO 64080
# 1    814 S Crane St, Independence, MO 64050
# 2  7001 S Benton Ave, Kansas City, MO 64132
# 3   5921 Indiana Ave, Kansas City, MO 64130
# 4   4421 College Ave, Kansas City, MO 64130
#
# [5 rows x 27 columns]

# %%
#County
#All of the values contain county at the end, so I want to remove that

davidimport["County"] = davidimport["County"].str.replace(" County", "", regex=False)

# %%
#Change currency columns to numbers

for col in ["Opening Bid"]:
    davidimport.loc[:, col] = (
        davidimport[col]
        .astype(str)
        .str.replace(r"[\$,]", "", regex=True)
        .astype(float)
    )

# %%
davidimport.loc[
    davidimport["Status"] == "Canceled",
    ["Status", "Opening Bid"]
].head(20)
# Out:
#        Status  Opening Bid
# 0    Canceled          NaN
# 8    Canceled    175560.00
# 13   Canceled          NaN
# 27   Canceled          NaN
# 34   Canceled          NaN
# 38   Canceled          NaN
# 51   Canceled          NaN
# 56   Canceled          NaN
# 61   Canceled          NaN
# 63   Canceled          NaN
# 97   Canceled          NaN
# 103  Canceled          NaN
# 110  Canceled          NaN
# 112  Canceled          NaN
# 113  Canceled          NaN
# 114  Canceled    425616.87
# 129  Canceled          NaN
# 145  Canceled          NaN
# 146  Canceled          NaN
# 147  Canceled          NaN

# %%
#Update Auction Status 

davidimport["Status"] = np.where(
    davidimport["Status"] == "Canceled",
    "Cancelled",
    ""
)

# %%
#Update Opening Bid

davidimport["Opening Bid"] = davidimport["Opening Bid"].astype("string")

davidimport.loc[
    davidimport["Status"].str.strip().str.upper() == "CANCELLED",
    "Opening Bid"
] = ""

# %%
davidimport.loc[
    davidimport["Status"] == "Cancelled",
    ["Status", "Opening Bid"]
].head(20)
# Out:
#         Status Opening Bid
# 0    Cancelled
# 8    Cancelled
# 13   Cancelled
# 27   Cancelled
# 34   Cancelled
# 38   Cancelled
# 51   Cancelled
# 56   Cancelled
# 61   Cancelled
# 63   Cancelled
# 97   Cancelled
# 103  Cancelled
# 110  Cancelled
# 112  Cancelled
# 113  Cancelled
# 114  Cancelled
# 129  Cancelled
# 145  Cancelled
# 146  Cancelled
# 147  Cancelled

# %%
#Change column names
davidimport = davidimport.rename(columns={
    "Date": "Auction Date Updated",
    "Time": "Auction Sale Time",
    "Owner Name": "Property Owner Name",
    "Square Feet": "Bldg Sq Ft",
    "Trustee": "Auction Trustee",
    "File #": "NS Trustee Sale Number",
    "Opening Bid": "Auction Opening Bid",
    "Status": "Auction Status",
})

# %%
davidimport.head()
# Out:
#     County Auction Date Updated Auction Sale Time            Address  \
# 0     Cass           01-12-2026             09:00     409 Vermont St
# 1  Jackson           01-12-2026             10:00     814 S Crane St
# 2  Jackson           01-12-2026             10:00  7001 S Benton Ave
# 3  Jackson           01-12-2026             10:00   5921 Indiana Ave
# 4  Jackson           01-12-2026             10:00   4421 College Ave
#
#             City    Zip          Property Owner Name  \
# 0  Pleasant Hill  64080             Erin R Pickering
# 1   Independence  64050  SPS Platinum Properties LLC
# 2    Kansas City  64132  SPS Platinum Properties LLC
# 3    Kansas City  64130  SPS Platinum Properties LLC
# 4    Kansas City  64130  SPS Platinum Properties LLC
#
#                                  Mailing Address  Bedrooms  Bathrooms  ...  \
# 0        409 Vermont St, Pleasant Hill, MO 64080       3.0        NaN  ...
# 1  511 Delaware St Ste 100 Kansas City, MO 64105       3.0        1.0  ...
# 2       7001 S Benton Ave, Kansas City, MO 64132       3.0        1.0  ...
# 3  10120 W Flamingo Rd Ste 4 Las Vegas, NV 89147       3.0        1.0  ...
# 4  511 Delaware St Ste 100 Kansas City, MO 64105       2.0        1.0  ...
#
#    Assessed Value  Proj. Opening Bid Original Loan Amount  \
# 0        204700.0           114778.0              89380.0
# 1        173500.0                NaN             856000.0
# 2        118700.0                NaN             856000.0
# 3        128800.0                NaN             856000.0
# 4        129900.0                NaN             856000.0
#
#                  APN Number Auction Status Action Comments  \
# 0                   1903700      Cancelled    NaN      NaN
# 1  26-620-06-17-00-0-00-000                   NaN      NaN
# 2  46-420-28-02-00-0-00-000                   NaN      NaN
# 3  46-310-02-20-00-0-00-000                   NaN      NaN
# 4  31-420-16-04-00-0-00-000                   NaN      NaN
#
#                             APN       Market  \
# 0     KCMO.409_VERMONT_ST_64080  Kansas City
# 1     KCMO.814_S_CRANE_ST_64050  Kansas City
# 2  KCMO.7001_S_BENTON_AVE_64132  Kansas City
# 3   KCMO.5921_INDIANA_AVE_64130  Kansas City
# 4   KCMO.4421_COLLEGE_AVE_64130  Kansas City
#
#                                   Last Name
# 0   409 Vermont St, Pleasant Hill, MO 64080
# 1    814 S Crane St, Independence, MO 64050
# 2  7001 S Benton Ave, Kansas City, MO 64132
# 3   5921 Indiana Ave, Kansas City, MO 64130
# 4   4421 College Ave, Kansas City, MO 64130
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Auction Trustee Lookups

# %%
contacts = pd.read_csv('sf_data/trusteecontacts.csv')

# %%
# Clean up column names if there are leading/trailing spaces
#contacts.columns = contacts.columns.str.strip()

# %%
#Normalize text for Contact Name and Associated Names

def norm(s):
    if pd.isna(s):
        return ""
    s = str(s).upper()
    s = s.replace("\u00A0", " ")              # non-breaking spaces
    s = re.sub(r"[^\w\s]", " ", s)            # remove punctuation
    s = re.sub(r"\s+", " ", s).strip()        # collapse spaces
    return s

contacts["contact_name_norm"] = contacts["Contact: Contact Name"].map(norm)
contacts["assoc_norm"] = contacts["Associated Names"].map(norm)  # can be blank

# %%
#contacts["contact_name_norm"] = contacts["Contact: Contact Name"]
#contacts["assoc_norm"] = contacts["Associated Names"]
#davidimport["trustee_norm"] = davidimport["Auction Trustee"]

# %%
#Normalize trustee names in the auction data

davidimport["trustee_norm"] = davidimport["Auction Trustee"].map(norm)

# %%
#Find exact matches

exact_map = dict(zip(contacts["contact_name_norm"], contacts["Contact: Contact Name"]))
davidimport["Auction Trustee (Lookup)"] = davidimport["trustee_norm"].map(exact_map)

# %%
#Find contains matches

def contains_in_contact_name(trustee_norm_value: str):
    if not trustee_norm_value:
        return None

    # find first contact where contact name contains trustee value
    hits = contacts.loc[
        contacts["contact_name_norm"].str.contains(re.escape(trustee_norm_value), na=False),
        "Contact: Contact Name"
    ]
    return hits.iloc[0] if len(hits) else None

mask = davidimport["Auction Trustee (Lookup)"].isna() & (davidimport["trustee_norm"] != "")
davidimport.loc[mask, "Auction Trustee (Lookup)"] = davidimport.loc[mask, "trustee_norm"].map(contains_in_contact_name)

# %%
#Find contains matches in associated names

def contains_in_associated(trustee_norm_value: str):
    if not trustee_norm_value:
        return None

    hits = contacts.loc[
        contacts["assoc_norm"].str.contains(re.escape(trustee_norm_value), na=False),
        "Contact: Contact Name"
    ]
    return hits.iloc[0] if len(hits) else None

mask = davidimport["Auction Trustee (Lookup)"].isna() & (davidimport["trustee_norm"] != "")
davidimport.loc[mask, "Auction Trustee (Lookup)"] = davidimport.loc[mask, "trustee_norm"].map(contains_in_associated)

# %%
#Collect and show unmatched rows

unmatched = (
    davidimport.loc[davidimport["Auction Trustee (Lookup)"].isna(),["Last Name", "Auction Trustee", "trustee_norm"]])

unmatched
# Out:
#                                     Last Name     Auction Trustee  \
# 64  4412 N Jackson Ave, Kansas City, MO 64117  Joel B. Laner, Esq
#
#         trustee_norm
# 64  JOEL B LANER ESQ

# %%
#Confirm what should match but didnt

missing = (
    davidimport.loc[davidimport["Auction Trustee (Lookup)"].isna(), "trustee_norm"]
    .dropna().drop_duplicates()
)

# which of these are present as a normalized contact name?
present_mask = missing.isin(contacts["contact_name_norm"])
missing_not_in_contacts = missing[~present_mask]

missing_not_in_contacts.head(50)
# Out:
# 64    JOEL B LANER ESQ
# Name: trustee_norm, dtype: object

# %%
davidimport.to_csv("export_data/davidimport.csv", index=False)
